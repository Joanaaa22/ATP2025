# %%
Lista=[]
import random 

def criaLista(N):
    global Lista 
    Lista=[]
    n = 1 
    while n <= N:
        n = n + 1
        Lista.append(random.randrange(1, 101))
    return Lista

def LerLista(N):
    global Lista 
    Lista=[]
    k=0
    while k < N:
        k = k + 1
        Lista.append(int(input("introduza um número")))
    return Lista

def somaLista(N):
    global Lista 
    soma = 0
    for n in N:
        soma = soma + n 
    return (soma)

def mediaLista(N):
    global Lista
    soma = 0
    for n in N: 
        soma = soma + n 
    return (soma/len(Lista))

def maiorLista(N):
    global Lista 
    maior=N[0]
    for x in N:
        if x>maior:
            maior=x
    return maior

def menorLista(N):
    global Lista 
    menor=N[0]
    for x in N:
        if x<menor:
            menor=x
    return menor 

def estaOrdenadaC(N):
    global Lista 
    for i in range(len(N) - 1):
        if N[i] > N[i + 1]:
            return "Não"
    return "Sim"

def estaOrdenadaD(N):
    global Lista 
    for i in range(len(N) - 1):
        if N[i] < N[i + 1]:
            return "Não"
    return "Sim"

def indiceDe(N, elem):
    cond=-1
    if elem in N:
        cond=N.index(elem)+1
    return cond 


modo=-1

while modo != 0:
    modo = int(input("Seleciona um modo ( (1) Criar Lista, (2) Ler Lista, (3) Soma, (4) Média, (5) Maior, (6) Menor, (7) Esta ordenado por ordem crescente, (8) Esta ordenado por ordem decrescente, (9) Procura um elemento, (0) Sair)"))

    if modo == 1:
        print(criaLista(int(input("Introduza a quantidade de números que quer na lista"))))

    elif modo == 2:
        print(LerLista(int(input("Introduza a quantidade de números que quer na lista"))))

    elif modo == 3:
        print(somaLista(Lista))

    elif modo == 4:
        print(mediaLista(Lista))

    elif modo == 5:
        print(maiorLista(Lista))

    elif modo == 6:
        print(menorLista(Lista))

    elif modo == 7:
        resultado=estaOrdenadaC(Lista)
        print(resultado)
    
    elif modo == 8:
        resultado2=estaOrdenadaD(Lista)
        print(resultado)

    elif modo == 9:
        print(Lista)
        print(indiceDe(Lista,int(input("Procura um número"))))

if modo == 0:
    print("Termina.")
# Out:
# [33, 41, 29, 96]
# [5, 8]
# 13
# 13
# 6.5
# 8
# 5
# Sim
# Sim
# [5, 8]
# -1
# Termina.
